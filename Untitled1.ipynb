# %%
import turtle, random
man = turtle.Turtle()
pat = turtle.Turtle()
titwl = turtle.Turtle()
screen = pat.getscreen()
pat.color("white")
man.color("orange")
titwl.color("yellow")
screen.bgcolor("black")
pat.penup()
pat.goto(-300,-300)
words=["cory","dugksycekugyDceguy","rwfgefqwiugyewfquyi"]

def Title():
    titwl.penup()
    titwl.setpos(-300,250)
    titwl.write("HANG-MAN", font=("Arial", 100, "normal"))
def hanger():
    man.penup()
    man.back(75)
    man.left(90)
    man.back(150)
    man.pendown()
    man.forward(367)
    man.right(90)
    man.forward(75)
    man.right(90)
    man.forward(25)
    man.penup()
    man.forward(100)
    man.left(90)
    man.pendown()
def Head():
    man.penup()
    man.goto(0,90)
    man.pendown()
    man.circle(50)
    man.right(90)
def Body():
    man.forward(100)
    man.penup()
    man.back(50)
    man.pendown()
def lefta():
    man.right(45)
    man.forward(50)
    man.penup()
    man.back(50)
    man.left(90)
    man.pendown()
def righta():
    man.forward(50)
    man.penup()
    man.back(50)
    man.right(45)
def leftl():
    man.forward(50)
    man.right(45)
    man.pendown()
    man.forward(75)
    man.penup()
    man.back(75)
    man.left(90)
def rightl():
    man.pendown()
    man.forward(75)
def linedraw():
    def lines():
        pat.pendown()
        pat.forward(30)
        pat.penup()
        pat.forward(10)
    wordcount = input("how many letters")
    wordcount = int(wordcount)
    for z in range(wordcount):
        lines()
    pat.penup()
    pat.penup()
def priword():
    #for i in range(len(words)):
        #for x in words:
            pat.goto(-310,-300)
            pat.forward(5)
            pat.write(words[0:1],font=("Arial", 35, "normal"))
            pat.forward(35)

linedraw()
Title()
hanger()
Head()
Body()
lefta()
righta()
leftl()
rightl()
#priword()
for letter in words:
    print(letter)
# Out:
# how many letters5
# cory
# dugksycekugyDceguy
# rwfgefqwiugyewfquyi
