# %%
def displayContacts(contacts):
    if not contacts:
        print("Contacts is empty")
    else: 
        print("Contact List: ")
        for key, value in contacts.items():
            print(f"{key}: {value}")

def addContact(contacts, contact):
    contactID = str(len(contacts) + 1)
    contacts[contactID] = contact
    print(f"Added '{contact}' to the playlist with ID: {contactID}")
            

def saveContact(contacts, file):
    with open(file, 'w') as file:
        for key, value in file.items():
            file.write(f"{key}:{value}\n")

            
def loadContacts(file):
    try:
        contacts = {}
        with open(file, 'r') as file:
            for line in file:
                key, value = line.strip().split(':', 1)
                file[key] = value
        return contacts
    except FileNotFoundError:
        return {}
def main():
    
    file='/Users/cory/Development/contacts.txt'
    contacts = loadContacts(file)
    while True: 
        print("\nMenu:")
        print("1. Contacts")
        print("2. Search Contacts")
        print("3. Add Contacdt")
        print("4. Delete Contact")
        print("5. Save and Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            displayContacts(contacts)
        elif choice == '2':
            contact = input("Enter the song to search: ")
            searchContact(contacts, contact)
        elif choice == '3':
            contact = input("Enter the song to add: ")
            addContact(contacts, contact)
        elif choice == '4':
            contact = input("Enter the song to delete: ")
            deleteContact(contacts, contact)
        elif choice == '5':
            saveContact(contacts, file)
            print("Playlist saved. Exiting the program.")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 5.")

main()
# Out:
# Menu:
# 1. Contacts
# 2. Search Contacts
# 3. Add Contacdt
# 4. Delete Contact
# 5. Save and Exit
# Enter your choice (1-5): 3
# Enter the song to add: freebird
# Added 'freebird' to the playlist with ID: 1
#
# Menu:
# 1. Contacts
# 2. Search Contacts
# 3. Add Contacdt
# 4. Delete Contact
# 5. Save and Exit
# Enter your choice (1-5): 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jl/2k4dhd7s3rv_cncxt1zks9_c0000gq/T/ipykernel_4911/3271733307.py in <module>
#      61             print("Invalid choice. Please enter a number between 1 and 5.")
#      62
# ---> 63 main()
#
# /var/folders/jl/2k4dhd7s3rv_cncxt1zks9_c0000gq/T/ipykernel_4911/3271733307.py in main()
#      55             deleteContact(contacts, contact)
#      56         elif choice == '5':
# ---> 57             saveContact(contacts, file)
# ...

# %%
def displayContacts(contacts):
    if not contacts:
        print("Contacts is empty")
    else: 
        print("Contact List: ")
        for key, value in contacts.items():
            print(f"{key}: {value}")

def addContact(contacts, contact):
    contactID = str(len(contacts) + 1)
    contacts[contactID] = contact
    print(f"Added '{contact}' to the contacts with ID: {contactID}")
            

def saveContacts(contacts, file):
    with open(file, 'w') as contacts_file:
        for key, value in contacts.items():
            contacts_file.write(f"{key}:{value}\n")

def loadContacts(file):
    try:
        contacts = {}
        with open(file, 'r') as contacts_file:
            for line in contacts_file:
                key, value = line.strip().split(':', 1)
                contacts[key] = value
        return contacts
    except FileNotFoundError:
        return {}

def searchContact(contacts, contact):
    # Function placeholder for searching contact
    pass

def deleteContact(contacts, contact):
    # Function placeholder for deleting contact
    pass

def main():
    file = '/Users/cory/Development/contacts.txt'
    contacts = loadContacts(file)
    
    while True: 
        print("\nMenu:")
        print("1. Contacts")
        print("2. Search Contacts")
        print("3. Add Contact")
        print("4. Delete Contact")
        print("5. Save and Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            displayContacts(contacts)
        elif choice == '2':
            contact = input("Enter the contact to search: ")
            searchContact(contacts, contact)
        elif choice == '3':
            contact = input("Enter the contact to add: ")
            addContact(contacts, contact)
        elif choice == '4':
            contact = input("Enter the contact to delete: ")
            deleteContact(contacts, contact)
        elif choice == '5':
            saveContacts(contacts, file)
            print("Contacts saved. Exiting the program.")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 5.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Contacts
# 2. Search Contacts
# 3. Add Contact
# 4. Delete Contact
# 5. Save and Exit
# Enter your choice (1-5): 1
# Contact List:
# 1: cory
#
# Menu:
# 1. Contacts
# 2. Search Contacts
# 3. Add Contact
# 4. Delete Contact
# 5. Save and Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/jl/2k4dhd7s3rv_cncxt1zks9_c0000gq/T/ipykernel_4911/2250910645.py in <module>
#      70
#      71 if __name__ == "__main__":
# ---> 72     main()
#
# /var/folders/jl/2k4dhd7s3rv_cncxt1zks9_c0000gq/T/ipykernel_4911/2250910645.py in main()
#      49         print("5. Save and Exit")
#      50
# ---> 51         choice = input("Enter your choice (1-5): ")
#      52
#      53         if choice == '1':
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
